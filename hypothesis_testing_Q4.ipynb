# %% [markdown]
# Chi2 contengency independence test
#
# Q4. TeleCall uses 4 centers around the globe to process customer order forms. They audit a certain % of the customer order forms. Any error in order form renders it defective and has to be reworked before processing. The manager wants to check whether the defective % varies by centre. Please analyze the data at 5% significance level and help the manager draw appropriate inferences.

# %% [markdown]
# We are going to conduct a Test of Independence using Chi-Square
#  test with Contingency table
# We need to check whether the mean of any of these samples are different or the same?

# %% [markdown]
# # Step 1

# %% [markdown]
# Make two Hypothesis one contradicting to other
# Null Hypothesis is want we want to prove
#
# *   **Null Hypothesis**: mean u1=u2=u3=u4
# *   **Alternative Hypthosis**: Atleast One of them is Different

# %% [markdown]
# # Step 2

# %% [markdown]
# Decide a cut-off value
# Significance 5%
# alpha = 0.05

# %% [markdown]
# # Step 3

# %% [markdown]
# # Collecting evidence and inferencing

# %%
from google.colab import drive
drive.mount('/content/drive')
# !ls '/content/drive/My Drive/Assignments/Hypothesis Testing'
# Out:
# Mounted at /content/drive
# BuyerRatio.csv			    hypothesis_testing_Q2.ipynb
# Costomer+OrderForm.csv		    hypothesis_testing_Q3.ipynb
# Cutlets.csv			    hypothesis_testing_Q4.ipynb
# Hypothesis_Testing_Assignment.pptx  LabTAT.csv
# hypothesis_testing_Q1.ipynb

# %%
import os
os.getcwd()
os.chdir('drive/My Drive/Assignments/Hypothesis Testing')

os.getcwd()
os.listdir()
# Out:
# ['Costomer+OrderForm.csv',
#  'LabTAT.csv',
#  'Hypothesis_Testing_Assignment.pptx',
#  'Cutlets.csv',
#  'BuyerRatio.csv',
#  'hypothesis_testing_Q1.ipynb',
#  'hypothesis_testing_Q2.ipynb',
#  'hypothesis_testing_Q3.ipynb',
#  'hypothesis_testing_Q4.ipynb']

# %%
import scipy.stats as stats
import statsmodels.api as sm
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
centers = pd.read_csv('Customer_OrderForm.csv')
centers.head(10)
# Out:
#   Phillippines   Indonesia       Malta       India
# 0   Error Free  Error Free   Defective  Error Free
# 1   Error Free  Error Free  Error Free   Defective
# 2   Error Free   Defective   Defective  Error Free
# 3   Error Free  Error Free  Error Free  Error Free
# 4   Error Free  Error Free   Defective  Error Free
# 5   Error Free  Error Free  Error Free  Error Free
# 6   Error Free   Defective  Error Free  Error Free
# 7   Error Free  Error Free  Error Free  Error Free
# 8   Error Free  Error Free  Error Free  Error Free
# 9   Error Free  Error Free  Error Free  Error Free

# %% [markdown]
# # Applying Descriptive statistics

# %%
centers.describe()
# Out:
#        Phillippines   Indonesia       Malta       India
# count           300         300         300         300
# unique            2           2           2           2
# top      Error Free  Error Free  Error Free  Error Free
# freq            271         267         269         280

# %% [markdown]
# # Checking for Null Values

# %%
centers.isnull().sum()
# Out:
# Phillippines    0
# Indonesia       0
# Malta           0
# India           0
# dtype: int64

# %% [markdown]
# # Checking the data type

# %%
centers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Phillippines  300 non-null    object
#  1   Indonesia     300 non-null    object
#  2   Malta         300 non-null    object
#  3   India         300 non-null    object
# dtypes: object(4)
# memory usage: 9.5+ KB

# %% [markdown]
# # Checking Valus counts in data

# %%
print(centers['Phillippines'].value_counts(),'\n',centers['Indonesia'].value_counts(),'\n',centers['Malta'].value_counts(),'\n',centers['India'].value_counts())
# Out:
# Error Free    271
# Defective      29
# Name: Phillippines, dtype: int64
#  Error Free    267
# Defective      33
# Name: Indonesia, dtype: int64
#  Error Free    269
# Defective      31
# Name: Malta, dtype: int64
#  Error Free    280
# Defective      20
# Name: India, dtype: int64

# %% [markdown]
# # Creating Contingency table

# %%
contingency_table = [[271,267,269,280],
                    [29,33,31,20]]
print(contingency_table)
# Out:
# [[271, 267, 269, 280], [29, 33, 31, 20]]

# %% [markdown]
# # Calculating Expected Values for Observed data

# %%
stat, p, df, exp = stats.chi2_contingency(contingency_table)
print("Statistics = ",stat,"\n",'P_Value = ', p,'\n', 'degree of freedom =', df,'\n', 'Expected Values = ', exp)
# Out:
# Statistics =  3.858960685820355
#  P_Value =  0.2771020991233135
#  degree of freedom = 3
#  Expected Values =  [[271.75 271.75 271.75 271.75]
#  [ 28.25  28.25  28.25  28.25]]

# %% [markdown]
# # Defining Expected values and observed values

# %%
observed = np.array([271, 267, 269, 280, 29, 33, 31, 20])
expected = np.array([271.75, 271.75, 271.75, 271.75, 28.25, 28.25, 28.25, 28.25])

# %% [markdown]
# # **Step 4**

# %% [markdown]
# # Compare Evidences with Hypothesis using t-statictic

# %%
test_statistic , p_value = stats.chisquare(observed, expected, ddof = df)
print("Test Statistic = ",test_statistic,'\n', 'p_value =',p_value)
# Out:
# Test Statistic =  3.858960685820355
#  p_value = 0.4254298144535761

# %% [markdown]
# # Interpriting p-value

# %% [markdown]
# if p_value <= alpha:'We reject Null Hypothesis there is a significance difference between customer order forms from the different centers
# else:'We fail to reject Null hypothesis'

# %%
alpha = 0.05
print('Significnace=%.3f, p=%.3f' % (alpha, p_value))
if p_value <= alpha:
    print('We reject Null Hypothesis there is a significance difference between TAT of reports of the laboratories')
else:
    print('We fail to reject Null hypothesis')
# Out:
# Significnace=0.050, p=0.425
# We fail to reject Null hypothesis

# %% [markdown]
# # We fail to reject Null Hypothesis because of lack of evidence.
